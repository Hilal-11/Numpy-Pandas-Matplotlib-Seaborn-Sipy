# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
temp = pd.Series([10 , 11 , 132 , 14 , 15 , 16 , 17 , 18 , 19 , 20])
def sigmoid(x): 
    return 1 / (1 + np.exp(-x))
temp_sigmoid = sigmoid(temp)
temp_sigmoid
# Out:
# 0    0.999955
# 1    0.999983
# 2    1.000000
# 3    0.999999
# 4    1.000000
# 5    1.000000
# 6    1.000000
# 7    1.000000
# 8    1.000000
# 9    1.000000
# dtype: float64

# %%
data = pd.Series([12 , 13 , 14 , 15 , 16 , 17 , 18 , 19 , 20])

def area_circle(r):
    return np.pi * r * r;

areas = area_circle(data)
areas
# Out:
# 0     452.389342
# 1     530.929158
# 2     615.752160
# 3     706.858347
# 4     804.247719
# 5     907.920277
# 6    1017.876020
# 7    1134.114948
# 8    1256.637061
# dtype: float64

# %%
data2 = pd.Series([12 , 13 , 14 , 15 , 16 , 17 , 18 , 19 , 20]).apply(lambda x: x % 2 == 0)
data2
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# 5    False
# 6     True
# 7    False
# 8     True
# dtype: bool

# %%
data3 = pd.Series([12 , 13 , 14 , 15 , 16 , 17 , 18 , 19 , 20]).apply(lambda val: 1 / (1 + np.exp(-val)))
data3
# Out:
# 0    0.999994
# 1    0.999998
# 2    0.999999
# 3    1.000000
# 4    1.000000
# 5    1.000000
# 6    1.000000
# 7    1.000000
# 8    1.000000
# dtype: float64

# %%
data_points = pd.DataFrame(
    {
        '1st point': [(1 , 2) , (3 , 4) , (5 , 6) , (7 , 8)],
        '2nd point': [(9 , 10) , (11 , 12) , (13 , 14) , (15 , 16)]
    }
)
data_points
# Out:
#   1st point 2nd point
# 0    (1, 2)   (9, 10)
# 1    (3, 4)  (11, 12)
# 2    (5, 6)  (13, 14)
# 3    (7, 8)  (15, 16)

# %%
def euclidean_distance(row):
    A = row['1st point']
    B = row['2nd point']
    return ((A[0] - B[0]) ** 2 + (A[1] - B[1]) ** 2)**0.5
data_points['distance'] = data_points.apply(euclidean_distance , axis = 1)
data_points
# Out:
#   1st point 2nd point   distance
# 0    (1, 2)   (9, 10)  11.313708
# 1    (3, 4)  (11, 12)  11.313708
# 2    (5, 6)  (13, 14)  11.313708
# 3    (7, 8)  (15, 16)  11.313708

# %%
movies = pd.read_csv('movies.csv')
movies.head()

genres = movies.groupby('genres')
genres.max()
# Out:
#                                           title_x    imdb_id  \
# genres
# Action                                 Vidyaarthi  tt7059844
# Action|Adventure                         Zokkomon  tt7463730
# Action|Adventure|Animation  Toonpur Ka Super Hero  tt2404027
# Action|Adventure|Comedy             Total Dhamaal  tt7639372
# Action|Adventure|Crime                  Jai Veeru  tt1369669
# ...                                           ...        ...
# Romance|Thriller                Valentine's Night  tt2346744
# Sci-Fi                              Aalaap (film)  tt2243336
# Sport                                    22 Yards  tt9496212
# Thriller                       Yeh Saali Aashiqui  tt9795264
# War                                 Battalion 609  tt9472208
#
#                                                                   poster_path  \
# genres
# Action                      https://upload.wikimedia.org/wikipedia/en/thum...
# ...
