# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Reading CSV Files using Pandas

# %%
moviesData = pd.read_csv("bollywood.csv")
# moviesData.dtypes
moviesData
# Out:
#                                      movie              lead
# 0                 Uri: The Surgical Strike     Vicky Kaushal
# 1                            Battalion 609       Vicky Ahuja
# 2     The Accidental Prime Minister (film)       Anupam Kher
# 3                          Why Cheat India     Emraan Hashmi
# 4                          Evening Shadows  Mona Ambegaonkar
# ...                                    ...               ...
# 1495                Hum Tumhare Hain Sanam    Shah Rukh Khan
# 1496                   Aankhen (2002 film)  Amitabh Bachchan
# 1497                       Saathiya (film)      Vivek Oberoi
# 1498                        Company (film)        Ajay Devgn
# 1499                  Awara Paagal Deewana      Akshay Kumar
#
# [1500 rows x 2 columns]

# %%
# customers = pd.read_csv("customer.csv")
# # customers.describe
# # customers.head()
# # customers.head(10)
# # customers.tail()
# customers.tail(20)

# %%
customers = pd.read_csv("customer.csv", index_col="age")
# customers.sample()
# customers.sample(5)

# %%
# customers.value_counts()

# %%
# customers.sort_values
customers.sort_index
# Out:
# <bound method DataFrame.sort_index of      gender   review education purchased
# age
# 30   Female  Average    School        No
# 68   Female     Poor        UG        No
# 70   Female     Good        PG        No
# 72   Female     Good        PG        No
# 16   Female  Average        UG        No
# 31   Female  Average    School       Yes
# 18     Male     Good    School        No
# 60   Female     Poor    School       Yes
# 65   Female  Average        UG        No
# 74     Male     Good        UG       Yes
# 98   Female     Good        UG       Yes
# 74     Male     Good        UG       Yes
# 51     Male     Poor    School        No
# 57   Female  Average    School        No
# 15     Male     Poor        PG       Yes
# 75     Male     Poor        UG        No
# 59     Male     Poor        UG       Yes
# 22   Female     Poor        UG       Yes
# 19     Male     Good    School        No
# 97     Male     Poor        PG       Yes
# 57   Female  Average    School       Yes
# ...

# %%
customers.count()
# Out:
# gender       50
# review       50
# education    50
# purchased    50
# dtype: int64

# %%
# customers.mean()
# customers.describe
# customers

# %%
moviesData.value_counts().head(50).plot(kind='barh')
# Out:
# <Axes: ylabel='movie,lead'>
